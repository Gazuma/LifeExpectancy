# %% [markdown]
# # Notebook for Linear Regression model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading the data to dataframe

# %%
life_expectancy = pd.read_csv("./Life_Expectancy_Data.csv")

# %% [markdown]
# # Converting categorical data to indicator variables

# %%
life_expectancy.isnull().sum()[np.where(life_expectancy.isnull().sum() != 0)[0]]
# Out:
# Life expectancy                     10
# Adult Mortality                     10
# Alcohol                            194
# Hepatitis B                        553
# BMI                                 34
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
life_expectancy.replace(0,np.nan)
# Out:
#       Year      Status  Life expectancy  Adult Mortality  infant deaths  \
# 0     2014  Developing             59.9            271.0           64.0
# 1     2013  Developing             59.9            268.0           66.0
# 2     2012  Developing             59.5            272.0           69.0
# 3     2011  Developing             59.2            275.0           71.0
# 4     2010  Developing             58.8            279.0           74.0
# ...    ...         ...              ...              ...            ...
# 2931  2004  Developing             44.3            723.0           27.0
# 2932  2003  Developing             44.5            715.0           26.0
# 2933  2002  Developing             44.8             73.0           25.0
# 2934  2001  Developing             45.3            686.0           25.0
# 2935  2000  Developing             46.0            665.0           24.0
#
#       Alcohol  percentage expenditure  Hepatitis B  Measles   BMI   ...  \
# ...

# %%
life_expectancy = life_expectancy.dropna()

# %%
life_expectancy
# Out:
#       Year      Status  Life expectancy  Adult Mortality  infant deaths  \
# 0     2014  Developing             59.9            271.0             64
# 1     2013  Developing             59.9            268.0             66
# 2     2012  Developing             59.5            272.0             69
# 3     2011  Developing             59.2            275.0             71
# 4     2010  Developing             58.8            279.0             74
# ...    ...         ...              ...              ...            ...
# 2931  2004  Developing             44.3            723.0             27
# 2932  2003  Developing             44.5            715.0             26
# 2933  2002  Developing             44.8             73.0             25
# 2934  2001  Developing             45.3            686.0             25
# 2935  2000  Developing             46.0            665.0             24
#
#       Alcohol  percentage expenditure  Hepatitis B  Measles   BMI   ...  \
# ...

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize = (20,20))
corr_matrix = life_expectancy.corr()
sns.heatmap(corr_matrix, annot = True)
plt.show()
# Out:
# C:\Users\deepr\AppData\Local\Temp\ipykernel_18260\1805107499.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = life_expectancy.corr()

# %%
# HIV ALCOHOL INCOME SCHOOLING MEASLES ADULT MORTALITY

# %%
sns.regplot(data = life_expectancy, x="Adult Mortality", y = "Life expectancy")
# Out:
# <AxesSubplot: xlabel='Adult Mortality', ylabel='Life expectancy'>

# %%
sns.regplot(data = life_expectancy, x=" HIV/AIDS", y = "Life expectancy")
# Out:
# <AxesSubplot: xlabel=' HIV/AIDS', ylabel='Life expectancy'>

# %%
sns.regplot(data = life_expectancy, x="Schooling", y = "Life expectancy")
# Out:
# <AxesSubplot: xlabel='Schooling', ylabel='Life expectancy'>

# %%
sns.regplot(data = life_expectancy, x="Income composition of resources", y = "Life expectancy")
# Out:
# <AxesSubplot: xlabel='Income composition of resources', ylabel='Life expectancy'>

# %%
life_expectancy = pd.get_dummies(life_expectancy, columns = ["Status"])

# %% [markdown]
# # Dividing the data into dependent and independent variables

# %%
X = life_expectancy.drop(columns = ["Life expectancy","Year","infant deaths","percentage expenditure","Hepatitis B","BMI ","under-five deaths ","Polio","Total expenditure","Diphtheria ","Measles ","GDP","Population"," thinness  1-19 years"," thinness 5-9 years","Alcohol"])

# %%
y = life_expectancy[["Life expectancy"]]

# %%
X
# Out:
#       Adult Mortality   HIV/AIDS  Income composition of resources  Schooling  \
# 0               271.0        0.1                            0.476       10.0
# 1               268.0        0.1                            0.470        9.9
# 2               272.0        0.1                            0.463        9.8
# 3               275.0        0.1                            0.454        9.5
# 4               279.0        0.1                            0.448        9.2
# ...               ...        ...                              ...        ...
# 2931            723.0       33.6                            0.407        9.2
# 2932            715.0       36.7                            0.418        9.5
# 2933             73.0       39.8                            0.427       10.0
# 2934            686.0       42.1                            0.427        9.8
# 2935            665.0       43.5                            0.434        9.8
#
#       Status_Developed  Status_Developing
# ...

# %%
y
# Out:
#       Life expectancy
# 0                59.9
# 1                59.9
# 2                59.5
# 3                59.2
# 4                58.8
# ...               ...
# 2931             44.3
# 2932             44.5
# 2933             44.8
# 2934             45.3
# 2935             46.0
#
# [1647 rows x 1 columns]

# %% [markdown]
# # Converting data to numpy arrays

# %%
X = np.array(X)

# %%
y = np.array(y)

# %% [markdown]
# # Splitting the data into training and testing

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# # Scaling data

# %%
from sklearn.preprocessing import StandardScaler

scaler_X = StandardScaler()
X_train = scaler_X.fit_transform(X_train)
X_test = scaler_X.transform(X_test)

scaler_y = StandardScaler()
y_train = scaler_y.fit_transform(y_train)
y_test = scaler_y.transform(y_test)

# %% [markdown]
# # Fitting the data to regression model

# %%
from sklearn.linear_model import LinearRegression

regression_model = LinearRegression(n_jobs = 20)
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression(n_jobs=20)

# %%
accuracy = regression_model.score(X_test, y_test)

# %%
accuracy
# Out:
# 0.8523437712680755

# %%
y_predict = regression_model.predict(X_test)
plt.plot(y_predict,y_test,"^",color = "r")
